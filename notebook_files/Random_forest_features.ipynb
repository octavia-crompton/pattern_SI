# %%
import os, sys, shutil
import gzip
import pickle
import json
import matplotlib.pylab as plt


sys.path.append('../src')

mymodules = ['plot_functions', 'ravel_fxns_RF']

for mod in mymodules:
    if mod in sys.modules:
        del sys.modules[mod]
        
from plot_functions import *
from ravel_fxns_RF import *

# %%
training_set = pd.read_pickle("/Users/octavia/Dropbox/SVEpattern/SI_datasets/SVE_training_data.pkl")

# %%
ravel_params = {'edge': 1, 'saturate' : 100, 
              'window': 'd2p',
              'gsigma' : [0, 1, 2], 
              "dx":1, 
              "uLs": [], 
              "blur": "1p",
              "bsigma_scale":[1,2]
             }
sim = training_set.iloc[100]
ptrn_dict = RF_patterns(sim.isvegc, ravel_params)

# %%
# print a list of all RF features
# print ptrn_dict.keys()

# %%
plt.figure(figsize = (10,5), )

ax = plt.subplot(131)
colormap(sim, ptrn_dict['isvegc'], ax, cmap = 'Greens', colorbar=False)
ax.set_title('Vegetation field')
plot_c(sim.isvegc, dx = sim.dx, ax = ax)

ax = plt.subplot(132)
colormap(sim, ptrn_dict['bareLV'], ax)
ax.set_title('Length of upslope \n bare patch')
plot_c(sim.isvegc, dx = sim.dx, ax = ax)

ax = plt.subplot(133)
colormap(sim, ptrn_dict['d2uV'], ax)
ax.set_title('Distance to upslope \n veg patch')
plot_c(sim.isvegc, dx = sim.dx, ax = ax)

# %%
plt.figure(figsize = (10,5), )

ax = plt.subplot(131)
colormap(sim, ptrn_dict['isvegc'], ax, cmap = 'Greens', colorbar=False)
ax.set_title('Vegetation field')
plot_c(sim.isvegc, dx = sim.dx, ax = ax)

ax = plt.subplot(132)
colormap(sim, ptrn_dict['blurred5'], ax)
ax.set_title('Blurred vegetation field \n ($\sigma = 5$)')
plot_c(sim.isvegc, dx = sim.dx, ax = ax)

ax = plt.subplot(133)
colormap(sim, ptrn_dict['blurred10'], ax)
ax.set_title('Blurred vegetation field \n ($\sigma = 10$)')
plot_c(sim.isvegc, dx = sim.dx, ax = ax)

# %%
plt.figure(figsize = (10,5), )

ax = plt.subplot(131)
colormap(sim, ptrn_dict['isvegc'], ax, cmap = 'Greens', colorbar=False)
ax.set_title('Vegetation field')
plot_c(sim.isvegc, dx = sim.dx, ax = ax)

ax = plt.subplot(132)
colormap(sim, ptrn_dict['upslope10'], ax)
ax.set_title('Upslope vegetation \n density ($L = 10$)')
plot_c(sim.isvegc, dx = sim.dx, ax = ax)

ax = plt.subplot(133)
colormap(sim, ptrn_dict['upslope20'], ax)
ax.set_title('Upslope vegetation \n  density ($L = 20$)')
plot_c(sim.isvegc, dx = sim.dx, ax = ax)

# %%
plt.figure(figsize = (11,5), )

ax = plt.subplot(131)
colormap(sim, ptrn_dict['isvegc'], ax, cmap = 'Greens', colorbar=False)
ax.set_title('Vegetation field')
plot_c(sim.isvegc, dx = sim.dx, ax = ax)

ax = plt.subplot(132)
colormap(sim, ptrn_dict['d2xB'], ax)
ax.set_title('Distance to nearest \n lateral  bare cell')
plot_c(sim.isvegc, dx = sim.dx, ax = ax)

ax = plt.subplot(133)
colormap(sim, ptrn_dict['d2xB_s2'], ax)
ax.set_title('Smoothed distance to nearest  \n  lateral bare cell ($\sigma =2$)')
plot_c(sim.isvegc, dx = sim.dx, ax = ax)
