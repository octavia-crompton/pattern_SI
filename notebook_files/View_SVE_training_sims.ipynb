# %%
import os, sys, shutil
import gzip
import pickle
import json
import matplotlib.pylab as plt
import pandas as pd
import numpy as np

sys.path.append('../src')

mymodules = ['plot_functions']

for mod in mymodules:
    if mod in sys.modules:
        del sys.modules[mod]
        
from plot_functions import *

# %%
training_set = pd.read_pickle("/Users/octavia/Dropbox/SVEpattern/SI_datasets/SVE_training_data.pkl")

# %%
key = training_set[np.all([training_set.p == training_set.p.max(),training_set.fV >0.4], axis = 0)].index[0]
sim  = training_set.loc[key]
triptych(sim)

# %%
plot_3D_veg(sim)

# %%
plot_3D_zinflc(sim)
